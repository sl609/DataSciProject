# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("z_stats_running.csv")

# %%
data.head()
# Out:
#         Unnamed: 0    label  RBC2barrier  inflation  scan_date   FOV  \
# 0          s000001  Healthy     0.549054   3.653717  4/25/2018  40.0
# 1         s000001A      NaN     0.500032   3.084198        NaN   NaN
# 2  s000001A_highBW  Healthy     0.500032   3.752991   7/5/2018  40.0
# 3  s000001B_highBW      NaN     0.509816   4.841125  7/17/2018  40.0
# 4  s000001H_highBW      NaN     0.534890   3.985413   6/6/2019  40.0
#
#     bandwidth  ven_defect   ven_low  ven_high  ...   rbc_low  rbc_high  \
# 0  398.596939    0.023437  0.121320  0.157695  ...  0.215962  0.046958
# 1         NaN         NaN       NaN       NaN  ...       NaN       NaN
# 2  797.193878    0.031266  0.152979  0.120574  ...  0.198637  0.116501
# 3  398.596939    0.078243  0.278559  0.078672  ...  0.223193  0.085782
# 4  797.193878    0.026686  0.153238  0.122349  ...  0.234980  0.047207
#
#     rbc_SNR  rbc_mean  rbc_median    rbc_SD  rbc_negative  KCO_esti  VA_esti  \
# 0  4.633671  0.317240    0.308668  0.163630      0.019019       NaN      NaN
# 1       NaN       NaN         NaN       NaN           NaN       NaN      NaN
# 2  3.053313  0.403706    0.376073  0.242379      0.032819       NaN      NaN
# 3  1.644846  0.289498    0.253236  0.385793      0.116564       NaN      NaN
# 4  2.713898  0.338014    0.329244  0.205531      0.051258       NaN      NaN
#
#    DLCO_esti
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'label', 'RBC2barrier', 'inflation', 'scan_date', 'FOV',
#        'bandwidth', 'ven_defect', 'ven_low', 'ven_high', 'ven_SNR', 'ven_mean',
#        'ven_median', 'ven_SD', 'bar_defect', 'bar_low', 'bar_high', 'bar_SNR',
#        'bar_mean', 'bar_median', 'bar_SD', 'bar_negative', 'rbc_defect',
#        'rbc_low', 'rbc_high', 'rbc_SNR', 'rbc_mean', 'rbc_median', 'rbc_SD',
#        'rbc_negative', 'KCO_esti', 'VA_esti', 'DLCO_esti'],
#       dtype='object')

# %%
use_data=data[['label','ven_mean','bar_mean','rbc_mean']]

use_data=use_data.dropna(subset=['label'])

use_data=use_data[use_data['label'].isin(['Healthy','COPD','NSIP'])]

# %%
use_data
# Out:
#        label  ven_mean  bar_mean  rbc_mean
# 0    Healthy  0.662467  0.519029  0.317240
# 2    Healthy  0.592356  0.708547  0.403706
# 18   Healthy  0.681617  0.837778  0.447216
# 21   Healthy  0.578364  0.620228  0.402708
# 22   Healthy  0.563647  0.796806  0.520189
# 24   Healthy  0.494540  0.762111  0.517091
# 25   Healthy  0.467822  1.058279  0.682910
# 26   Healthy  0.576420  0.561988  0.336131
# 27   Healthy  0.518060  0.721548  0.419167
# 28   Healthy  0.581919  0.514472  0.180952
# 29   Healthy  0.624276  0.715291  0.267783
# 30      COPD  0.453720  0.450536  0.142498
# 31      COPD  0.419271  0.521771  0.249814
# 32   Healthy  0.578256  0.724077  0.504462
# 33   Healthy  0.580497  0.832549  0.568708
# 34      NSIP  0.345085  1.162668  0.136821
# 35      NSIP  0.283200  1.082723  0.297896
# 36      NSIP  0.677897  0.828112  0.145856
# 37      NSIP  0.557476  0.962867  0.086055
# 38   Healthy  0.575829  1.053339  0.542359
# 39   Healthy  0.603219  0.838721  0.410323
# 40      NSIP  0.583055  0.594912  0.177097
# 41      NSIP  0.572412  1.013355  0.329046
# 42      NSIP  0.595191  1.170949  0.132408
# 43      NSIP  0.688543  0.722496  0.195226
# 44      NSIP  0.640666  0.837951  0.261393
# 45      NSIP  0.550481  1.606328  0.244898
# 46      NSIP  0.576738  1.024390  0.173485
# 47      NSIP  0.473937  0.722101  0.303733
# 48      NSIP  0.593145  0.919724  0.215859
# ..       ...       ...       ...       ...
# 219     COPD  0.388632  0.476504  0.109886
# 220     COPD  0.476679  0.603228  0.144696
# 221     COPD  0.270610  0.434795  0.152721
# 222     COPD  0.283045  0.453394  0.175522
# 223     COPD  0.400788  0.527011  0.114024
# 224     COPD  0.326304  0.457827  0.138622
# 225     COPD  0.245454  0.478726  0.123237
# 226     COPD  0.451798  0.498308  0.177539
# 227     COPD  0.331275  0.422090  0.099756
# 228     COPD  0.330883  0.420831  0.091801
# 229     COPD  0.458484  0.568623  0.217569
# 230     COPD  0.479733  0.606818  0.247595
# 231     COPD  0.454874  0.639000  0.208946
# 232     COPD  0.427974  0.715500  0.206533
# 233     COPD  0.358219  0.358121  0.112473
# 234     COPD  0.333104  0.391967  0.112496
# 235     COPD  0.281272  0.543789  0.157088
# 236     COPD  0.327781  0.527037  0.154221
# 237     COPD  0.369372  0.551766  0.172240
# 238     COPD  0.431253  0.571067  0.162208
# 239     COPD  0.395926  0.843442  0.344159
# 240     COPD  0.501842  0.892748  0.344363
# 241     COPD  0.337998  0.684083  0.212251
# 242     COPD  0.387727  0.734230  0.184718
# 243     COPD  0.384412  0.277615  0.087854
# 244     COPD  0.342031  0.278913  0.087912
# 245     COPD  0.421651  0.494311  0.108245
# 255     NSIP  0.661278  0.994537  0.158206
# 259  Healthy  0.700053  0.834758  0.537099
# 268     NSIP  0.628804  0.902345  0.152605
#
# [95 rows x 4 columns]

# %%
use_data['label']=pd.Categorical(use_data['label'])

# %%
use_data['code_label'] = use_data.label.cat.codes

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

h= use_data[use_data['label']=='Healthy'];
c= use_data[use_data['label']=='COPD'];
n= use_data[use_data['label']=='NSIP'];


ax.scatter(h['ven_mean'], h['bar_mean'], h['rbc_mean'], c='r', marker='o')
ax.scatter(c['ven_mean'], c['bar_mean'], c['rbc_mean'], c='b', marker='^')
ax.scatter(n['ven_mean'], n['bar_mean'], n['rbc_mean'], c='k', marker='x')

ax.set_xlabel('ven_mean')
ax.set_ylabel('bar_mean')
ax.set_zlabel('rbc_mean')

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

ax.scatter(h['ven_mean'], h['bar_mean'], c='r', marker='o')
ax.scatter(c['ven_mean'], c['bar_mean'], c='b', marker='^')
ax.scatter(n['ven_mean'], n['bar_mean'], c='k', marker='x')

ax.set_xlabel('ven_mean')
ax.set_ylabel('bar_mean')
# Out:
# Text(0, 0.5, 'bar_mean')

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

ax.scatter(h['bar_mean'], h['rbc_mean'], c='r', marker='o')
ax.scatter(c['bar_mean'], c['rbc_mean'], c='b', marker='^')
ax.scatter(n['bar_mean'], n['rbc_mean'], c='k', marker='x')

ax.set_xlabel('bar_mean')
ax.set_ylabel('rbc_mean')
# Out:
# Text(0, 0.5, 'rbc_mean')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9fb0a840b0f1> in <module>
# ----> 1 svm_data['code_label'].value_counts()
#
# NameError: name 'svm_data' is not defined

# %%
svm_data=use_data.drop('label', axis=1)

# %%
X=svm_data.drop('code_label', axis=1)
y=svm_data['code_label']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[7 0 0]
#  [3 5 0]
#  [0 0 4]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       1.00      0.62      0.77         8
#            2       1.00      1.00      1.00         4
#
#     accuracy                           0.84        19
#    macro avg       0.90      0.88      0.86        19
# weighted avg       0.89      0.84      0.84        19

# %% [markdown]
# Ref
# https://stackabuse.com/implementing-svm-and-kernel-svm-with-pythons-scikit-learn/
