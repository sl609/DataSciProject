# %%
# Basic Packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Additional Packages
import random
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import datasets, linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import KFold

random.seed(123)

# %% [markdown]
# # Import Data

# %%
df = pd.read_excel("data.xlsx")
df = df.dropna(subset = ['label'])
df.drop(columns = ['age'], inplace = True)
df = df.dropna()
df.head(10)
# Out:
#          subject label  RBC2barrier  Inflation   bandwidth  ven_defect  \
# 16       002-130   IPF      0.30260   2.214508  797.193878    0.020850
# 17   002-130_rep   IPF      0.30260   2.196838  797.193878    0.049093
# 21      003-013A   IPF      0.19224   3.191266  398.596939    0.073045
# 22      003-013B   IPF      0.21894   3.480804  398.596939    0.105445
# 23  003-013B_rep   IPF      0.21894   3.449341  797.193878    0.110928
# 24       003-014   IPF      0.27590   2.176666  797.193878    0.017273
# 25   003-014_rep   IPF      0.27590   2.150269  797.193878    0.015271
# 26      003-014A   IPF      0.27590   2.648010  797.193878    0.032834
# 27  003-014A_rep   IPF      0.27590   2.465210  797.193878    0.037150
# 28      003-014B   IPF      0.26077   2.723907  797.193878    0.086660
#
#      ven_low  ven_high    ven_SNR  ven_mean  ...  rbc_high   rbc_SNR  \
# 16  0.123779  0.143347  13.261325  0.616582  ...  0.066465  3.959749
# 17  0.243506  0.102687   9.655796  0.538779  ...  0.130581  3.162519
# 21  0.250424  0.073220   8.803432  0.552996  ...  0.033407  1.530583
# 22  0.292831  0.068044   8.694271  0.522884  ...  0.091593  2.166433
# 23  0.374633  0.051598   4.025500  0.439775  ...  0.162216  0.779660
# 24  0.145587  0.045019  16.615980  0.564594  ...  0.014343  4.754771
# 25  0.152853  0.051292  18.134405  0.563476  ...  0.007252  5.143344
# 26  0.206419  0.079763  13.653378  0.548241  ...  0.013784  3.424738
# 27  0.196026  0.062280  14.746538  0.543239  ...  0.016700  4.089562
# 28  0.185957  0.059816  17.600002  0.520253  ...  0.000874  4.811945
#
#     rbc_mean  rbc_median    rbc_SD  rbc_negative   fvc   fe1  fev1-fvc  \
# 16  0.325306    0.295653  0.214930      0.046510  35.8  36.0     100.7
# 17  0.390956    0.348991  0.293248      0.064929  35.8  36.0     100.7
# 21  0.192941    0.148458  0.198888      0.217226  56.0  59.0     105.0
# 22  0.267608    0.216779  0.263179      0.158944  49.0  54.0     111.0
# 23  0.384974    0.207698  0.893194      0.259440  49.0  54.0     111.0
# 24  0.263845    0.250648  0.168735      0.057259  59.0  60.0     103.0
# 25  0.245911    0.227628  0.157435      0.053037  59.0  60.0     103.0
# 26  0.264196    0.248966  0.172329      0.059018  62.0  61.0      98.0
# 27  0.275860    0.259576  0.178420      0.064063  62.0  61.0      98.0
# 28  0.244656    0.239328  0.138342      0.034832  57.0  67.0     106.0
#
#     fev25-75
# 16      37.7
# 17      37.7
# 21      76.0
# 22      96.0
# 23      96.0
# 24      68.0
# 25      68.0
# 26      39.0
# 27      39.0
# 28      83.0
#
# [10 rows x 32 columns]

# %%
del df['subject']
label = {'IPF': 1,'NSIP': 0}

df.label = [label[item] for item in df.label]
df.head(10)
# Out:
#     label  RBC2barrier  Inflation   bandwidth  ven_defect   ven_low  ven_high  \
# 16      1      0.30260   2.214508  797.193878    0.020850  0.123779  0.143347
# 17      1      0.30260   2.196838  797.193878    0.049093  0.243506  0.102687
# 21      1      0.19224   3.191266  398.596939    0.073045  0.250424  0.073220
# 22      1      0.21894   3.480804  398.596939    0.105445  0.292831  0.068044
# 23      1      0.21894   3.449341  797.193878    0.110928  0.374633  0.051598
# 24      1      0.27590   2.176666  797.193878    0.017273  0.145587  0.045019
# 25      1      0.27590   2.150269  797.193878    0.015271  0.152853  0.051292
# 26      1      0.27590   2.648010  797.193878    0.032834  0.206419  0.079763
# 27      1      0.27590   2.465210  797.193878    0.037150  0.196026  0.062280
# 28      1      0.26077   2.723907  797.193878    0.086660  0.185957  0.059816
#
#       ven_SNR  ven_mean  ven_median  ...  rbc_high   rbc_SNR  rbc_mean  \
# 16  13.261325  0.616582    0.634848  ...  0.066465  3.959749  0.325306
# 17   9.655796  0.538779    0.544480  ...  0.130581  3.162519  0.390956
# 21   8.803432  0.552996    0.569119  ...  0.033407  1.530583  0.192941
# 22   8.694271  0.522884    0.538891  ...  0.091593  2.166433  0.267608
# 23   4.025500  0.439775    0.426276  ...  0.162216  0.779660  0.384974
# 24  16.615980  0.564594    0.576405  ...  0.014343  4.754771  0.263845
# 25  18.134405  0.563476    0.571920  ...  0.007252  5.143344  0.245911
# 26  13.653378  0.548241    0.555600  ...  0.013784  3.424738  0.264196
# 27  14.746538  0.543239    0.554408  ...  0.016700  4.089562  0.275860
# 28  17.600002  0.520253    0.546030  ...  0.000874  4.811945  0.244656
#
#     rbc_median    rbc_SD  rbc_negative   fvc   fe1  fev1-fvc  fev25-75
# 16    0.295653  0.214930      0.046510  35.8  36.0     100.7      37.7
# 17    0.348991  0.293248      0.064929  35.8  36.0     100.7      37.7
# 21    0.148458  0.198888      0.217226  56.0  59.0     105.0      76.0
# 22    0.216779  0.263179      0.158944  49.0  54.0     111.0      96.0
# 23    0.207698  0.893194      0.259440  49.0  54.0     111.0      96.0
# 24    0.250648  0.168735      0.057259  59.0  60.0     103.0      68.0
# 25    0.227628  0.157435      0.053037  59.0  60.0     103.0      68.0
# 26    0.248966  0.172329      0.059018  62.0  61.0      98.0      39.0
# 27    0.259576  0.178420      0.064063  62.0  61.0      98.0      39.0
# 28    0.239328  0.138342      0.034832  57.0  67.0     106.0      83.0
#
# [10 rows x 31 columns]

# %%
y = df.label
df_feature = df.loc[:, df.columns != 'label']
X_train, X_test, y_train, y_test = train_test_split(df_feature, y, test_size = 0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
X_train
# Out:
# (66, 30) (66,)
# (17, 30) (17,)
#      RBC2barrier  Inflation   bandwidth  ven_defect   ven_low  ven_high  \
# 100     0.440550   3.181732  797.193878    0.054250  0.212950  0.127174
# 39      0.199360   2.117706  797.193878    0.084057  0.242503  0.101783
# 69      0.216270   2.324829  797.193878    0.030441  0.125991  0.153820
# 87      0.303422   2.264435  797.193878    0.007480  0.051091  0.260792
# 73      0.174715   1.498138  797.193878    0.005439  0.070278  0.218411
# ..           ...        ...         ...         ...       ...       ...
# 56      0.316840   3.290131  797.193878    0.124403  0.353637  0.052397
# 72      0.253934   1.690002  797.193878    0.344288  0.474159  0.027105
# 22      0.218940   3.480804  398.596939    0.105445  0.292831  0.068044
# 95      0.121001   2.524231  797.193878    0.018014  0.144099  0.113246
# 86      0.215033   2.168182  797.193878    0.022168  0.067392  0.327628
#
#        ven_SNR  ven_mean  ven_median    ven_SD  ...  rbc_high   rbc_SNR  \
# 100   9.109141  0.557122    0.571792  0.215860  ...  0.119779  3.296082
# 39    6.608916  0.522601    0.536523  0.223315  ...  0.074417  1.327632
# 69   20.595295  0.607885    0.622232  0.193349  ...  0.001418  6.528709
# 87   18.338360  0.702977    0.729053  0.157805  ...  0.027048  6.594280
# 73   18.580711  0.677897    0.698078  0.163482  ...  0.000020  2.598815
# ..         ...       ...         ...       ...  ...       ...       ...
# 56    5.866125  0.440746    0.430741  0.213581  ...  0.089703  1.329232
# 72   16.030020  0.283200    0.252031  0.187860  ...  0.024396  4.832035
# 22    8.694271  0.522884    0.538891  0.213962  ...  0.091593  2.166433
# 95   17.441665  0.595320    0.605936  0.179833  ...  0.001173  1.963606
# 86   21.346092  0.697747    0.738560  0.189771  ...  0.001548  5.119033
#
#      rbc_mean  rbc_median    rbc_SD  rbc_negative    fvc    fe1  fev1-fvc  \
# 100  0.404151    0.389107  0.273344      0.048945   78.0   81.0     104.0
# 39   0.287365    0.210400  0.507003      0.184068   37.0   39.0     105.8
# 69   0.251637    0.254026  0.120706      0.018049   77.0   92.0     119.0
# 87   0.352883    0.368117  0.177892      0.046805   45.0   49.0     108.0
# 73   0.145856    0.147968  0.106638      0.174329   40.0   40.0     103.0
# ..        ...         ...       ...           ...    ...    ...       ...
# 56   0.318293    0.235656  0.529969      0.147935  101.0  105.0     104.0
# 72   0.297896    0.285109  0.194599      0.019791   39.0   40.0     105.0
# 22   0.267608    0.216779  0.263179      0.158944   49.0   54.0     111.0
# 95   0.117324    0.102200  0.106570      0.185664   78.0   86.0     110.0
# 86   0.224368    0.220147  0.130667      0.058919   65.0   61.0      95.0
#
#      fev25-75
# 100      92.0
# 39       53.1
# 69      202.0
# 87       71.0
# 73       49.0
# ..        ...
# 56      108.0
# 72       54.0
# 22       96.0
# 95      122.0
# 86       47.0
#
# [66 rows x 30 columns]

# %%
rf_model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
rf_model.fit(X_train, y_train)
rf_predictions = rf_model.predict(X_test)

rf_probs = rf_model.predict_proba(X_test)[:, 1]
roc_value = roc_auc_score(y_test, rf_probs)

# %%
roc_auc_score(y_test, rf_probs)
# Out:
# 0.8560606060606061

# %%
fi = pd.DataFrame({'feature': list(X_train.columns),
                   'importance': rf_model.feature_importances_}).\
                    sort_values('importance', ascending = False)

# Display
fi.head()
# Out:
#         feature  importance
# 24       rbc_SD    0.051372
# 8    ven_median    0.050218
# 0   RBC2barrier    0.049861
# 28     fev1-fvc    0.046783
# 1     Inflation    0.044130
